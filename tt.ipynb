# %%
from train import *
from drawTools import *
from tensorflow.keras.models import load_model

# %%
modelDir = '1-results/2020_1128_1939/'

# %%
# load data
with open('%s/opt.pickle'%modelDir, 'rb') as fr:
    opt = pickle.load(fr)
print(opt)
# Out:
# {'dataDir': '0-data/res_process/eeg1/data0/', 'model': 'wavenet', 'epochs': 20, 'class_weights': array([0.78, 0.78, 1.  ]), 'batch_size': 64}

# %%
dataDir = opt['dataDir']

# %%
_, x_valid, x_test, _, y_valid, y_test = load_data(dataDir)

# %%
model =  load_model("%s/model.h5"%modelDir)

# %%
y_hat = model.pred

# %%
draw_cm(x_valid, y_valid, model)

# %%
draw_cm(x_test, y_test, model)
